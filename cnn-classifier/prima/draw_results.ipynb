# %%
from pylab import *
from draw_info import draw_acc, draw_loss, draw_val_acc, draw_val_loss
# %matplotlib inline

# %%
draw_acc()

# %%
loss_start = draw_loss()
print(loss_start)
# Out:
# 0.6943295001983643

# %%
draw_val_acc(val_acc_start = 1/4)

# %%
draw_val_loss(val_loss_start = loss_start)

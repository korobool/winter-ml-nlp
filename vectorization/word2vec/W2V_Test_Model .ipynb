# %%
from gensim.models import Word2Vec
model = Word2Vec.load('./w2v/w2v_model.bin')

# %%
print(model.similarity('woman', 'man'))
# Out:
# 0.962101066728

# %%
print(model.most_similar(positive=['generator', 'nuclear']))
# Out:
# [('surface', 0.9992244243621826), ('making', 0.9991644620895386), ('drive', 0.9989581108093262), ('openly', 0.9988642334938049), ('still', 0.9987912774085999), ('week', 0.998780369758606), ('personal', 0.9987556338310242), ('nearest', 0.9987467527389526), ('smiling', 0.9987455606460571), ('border', 0.99860680103302)]

# %%
model['star']
# Out:
# array([ 0.05457493, -0.06236292, -0.09902158,  0.0941259 ,  0.26389992,
#        -0.17518987, -0.01627337,  0.07168861, -0.26413244, -0.01634402,
#         0.0947292 ,  0.04507939,  0.02258342, -0.07679417,  0.18362164,
#         0.01118282, -0.36143473, -0.10624266,  0.04710277, -0.0569697 ,
#         0.05852954, -0.00071918,  0.20005712, -0.11441636,  0.21841821,
#        -0.00729579,  0.05420553, -0.1505641 , -0.17279957,  0.00790098,
#        -0.01740466, -0.12883748, -0.11585569,  0.29945648,  0.02087201,
#         0.16982466,  0.01307013, -0.12744899,  0.03625226, -0.15184613,
#        -0.00365875, -0.15787636,  0.04552827, -0.0220102 ,  0.20082754,
#         0.10076242,  0.06106903, -0.18501931,  0.19684806,  0.25048283,
#        -0.07193312,  0.04180195, -0.08885739,  0.04639959, -0.07010236,
#         0.03970397, -0.06225889,  0.03228299, -0.00202546,  0.05414293,
#         0.02525288, -0.11576091, -0.01951381, -0.00637394,  0.12243649,
# ...
